# %%
# bài 3:Nhập vào số nguyên dương n từ bàn phím. Kiểm tra xem số n có phải là số nguyên tốt hay không. Nếu là số nguyên tố thì in ra dòng text : “Đây là số nguyên tố”. Nếu không thì in ra: “Không phải là số nguyên tố”. 
n=int(input())
đếmước=0
for i in range(1,n+1,+1):
    if n%i==0:
        đếmước = đếmước +1
if đếmước ==2:
    print("Đây là số nguyên tố")
else:
    print("Không phải là số nguyên tố")
# Out:
# ---------------------------------------------------------------------------
# StdinNotImplementedError                  Traceback (most recent call last)
# <ipython-input-1-95b61198c6e5> in <module>
#       1 # bài 3:Nhập vào số nguyên dương n từ bàn phím. Kiểm tra xem số n có phải là số nguyên tốt hay không. Nếu là số nguyên tố thì in ra dòng text : “Đây là số nguyên tố”. Nếu không thì in ra: “Không phải là số nguyên tố”.
# ----> 2 n=int(input())
#       3 đếmước=0
#       4 for i in range(1,n+1,+1):
#       5     if n%i==0:
#
# /opt/conda/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     844         if not self._allow_stdin:
#     845             raise StdinNotImplementedError(
# --> 846                 "raw_input was called, but this frontend does not support input requests."
#     847             )
#     848         return self._input_request(str(prompt),
#
# ...

# %%
###### Bài 4: Nhập vào từ bàn phím số nguyên n. In ra tổng của các số thỏa mã hai điều kiện: nhỏ hơn n và là số chẵn.

n=int(input("Nhập số nguyên n="))
if n%2==0:
    tong_so_chan=((n-2)*n)//4
    print(tong_so_chan)
elif n%2==1:
    tong_so_le=(n**2)//4
    print(tong_so_le)

# %%
#bài 5:nhập vào số nguyên từ bàn phím. In ra tích của 2 nhân với các giá trị nhỏ n
n=int(input("nhập số nguyên n= "))
for i in range(1,n+1,+1):
    print("2*",i,"=",(2*i))

# %%
#Bài 6: In ra các số trong khoảng từ 10 → 50 thỏa mã điều kiện chia hết cho 2 , vừa chia hết cho 3. 
print("Các số vừa chia hết cho 2, vừa chia hết cho 3 là:")
for i in range(10,51,+1):
    if i%2==0 and i%3==0:
        print(i)

# %%
#Bài 2: Nhập vào số nguyên dương  n từ bàn phím. Tính và in ra n! (giai thừa)
n=int(input("nhập số nguyên n= "))
giaithua=1
for i in range(1,n+1,+1):
    giaithua=giaithua*i
print("giai thua cua", n ,'la', giaithua)

# %%
#Bài 1: Tính và in ra tích của 10 số tự nhiên đầu tiên . [1 →10].
giaithua=1
for i in range(1,11,+1):
    giaithua=giaithua*i
print("tích của 10 số tự nhiên đầu tiên là: ",giaithua)

# %%
#Bài 7:Viết một chương trình chấp nhận chuỗi là các dòng được nhập vào, chuyển các dòng này thành chữ in hoa và in ra màn hình. 
print("Nhập một câu viết: ")
n=input()
print("Ta được kết quả là: ")
print(n.upper())

# %%
#Bài 9:Yêu cầu người dùng cung cấp một chuỗi và cho biết đó có phải một palindrome không 
a=str(input("Nhập một cụm từ:" )) 
b=str(input("Nhập một cụm từ:"))
if a[::-1]==b:
    print("YES")
else:
    print("NO")

# %%
#Bài 8:Viết một chương trình chấp nhận đầu vào là một chuỗi các từ tách biệt bởi khoảng trắng, loại bỏ các từ trùng lặp rồi in chúng.

def tránh_lặp_từ(câu):
    chuỗi_kết_quả = ''
    ký_tự=  câu.split(" ")
    for ký_tự  in câu:
        if ký_tự not in chuỗi_kết_quả:
            chuỗi_kết_quả = chuỗi_kết_quả +ký_tự
    return chuỗi_kết_quả

câu=input()
print(tránh_lặp_từ(câu))

# %%
#Bài 10:Viết một chương trình chấp nhận chuỗi từ được phân tách bằng khoảng trống và in các từ chỉ gồm chữ số.
import re

string = input("nhập câu lệnh vào: ")
pattern = '\d+'

result = re.findall(pattern, string) 
print(result)

# %%
s = input("Nhập chuỗi của bạn:") 
words = [word for word in s.split(" ")]
print (" ".join(sorted(list(set(words)))))
##đây là cách trên mạng nhưng e chưa hiểu :)))

# %%
#Bài 8: làm lại
a=input("Nhập một chuỗi")
b= a.split()
def cau_moi(b):
    chuỗi=''
    for từ in b:    
        if từ not in chuỗi:   
           chuỗi = chuỗi + " " + từ
    return chuỗi
print(cau_moi(b))
