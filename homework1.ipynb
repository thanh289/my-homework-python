# %%
#Bài 1: Tính và in ra tích của 10 số tự nhiên đầu tiên . [1 →10].
giaithua=1
for i in range(1,11):
    giaithua=giaithua*i
print("tích của 10 số tự nhiên đầu tiên là: ",giaithua)
# Out:
# tích của 10 số tự nhiên đầu tiên là:  3628800

# %%
#Bài 2: Nhập vào số nguyên dương  n từ bàn phím. Tính và in ra n! (giai thừa)
n=int(input("nhập số nguyên n= "))
giaithua=1
for i in range(1,n+1):
    giaithua=giaithua*i
print("giai thua cua", n ,'la', giaithua)
# Out:
# nhập số nguyên n=  8
# giai thua cua 8 la 40320

# %%
# bài 3:Nhập vào số nguyên dương n từ bàn phím. Kiểm tra xem số n có phải là số nguyên tố hay không. Nếu là số nguyên tố thì in ra dòng text : “Đây là số nguyên tố”. Nếu không thì in ra: “Không phải là số nguyên tố”. 
n=int(input())
đếmước=0
for i in range(1,n+1):
    if n%i==0:
        đếmước = đếmước +1
if đếmước ==2:
    print("Đây là số nguyên tố")
else:
    print("Không phải là số nguyên tố")
# Out:
#  11
# Đây là số nguyên tố

# %%
#Bài 4: Nhập vào từ bàn phím số nguyên n. In ra tổng của các số thỏa mã hai điều kiện: nhỏ hơn n và là số chẵn.

n = int(input("Nhập vào một số nguyên bất kì:"))
s = 0
for i in range(2, n, 2):
    s += i
print('Tổng các số chẵn nhỏ hơn', n ,'là:', s)
# Out:
# Nhập vào một số nguyên bất kì: 9
# Tổng các số chẵn nhỏ hơn 9 là: 20

# %%
#bài 5:nhập vào số nguyên từ bàn phím. In ra tích của 2 nhân với các giá trị nhỏ n
n=int(input("Nhập số nguyên n= "))
for i in range(1,n+1):
    print("2*",i,"=",(2*i))
# Out:
# Nhập số nguyên n=  5
# 2* 1 = 2
# 2* 2 = 4
# 2* 3 = 6
# 2* 4 = 8
# 2* 5 = 10

# %%
#Bài 6: In ra các số trong khoảng từ 10 → 50 thỏa mã điều kiện chia hết cho 2 , vừa chia hết cho 3. 
print("Các số vừa chia hết cho 2, vừa chia hết cho 3 là:")
for i in range(10,51):
    if i%2==0 and i%3==0:
        print(i)
        
#cách khác:[elem for elem in range(10,51) if elem%2==0 and elem%3==0]
# Out:
# Các số vừa chia hết cho 2, vừa chia hết cho 3 là:
# 12
# 18
# 24
# 30
# 36
# 42
# 48

# %%
#Bài 7:Viết một chương trình chấp nhận chuỗi là các dòng được nhập vào, chuyển các dòng này thành chữ in hoa và in ra màn hình. 
n=input('Nhập một chuỗi:')
print("Ta được kết quả là: ",n.upper())
# Out:
# Nhập một chuỗi: hello everyone
# Ta được kết quả là:  HELLO EVERYONE

# %%
#Bài 8:Viết một chương trình chấp nhận đầu vào là một chuỗi các từ tách biệt bởi khoảng trắng, loại bỏ các từ trùng lặp rồi in chúng.

a=input("Nhập một chuỗi:")
b= a.split()
def cau_moi(b):
    chuỗi=''
    for từ in b:    
        if từ not in chuỗi:   
           chuỗi = chuỗi + " " + từ
    return chuỗi
print(cau_moi(b))
# Out:
# Nhập một chuỗi: xin xin chao    tat ca   moi nguoi nguoi
#  xin chao tat ca moi nguoi

# %%
#Bài 8:(cách a Duy)
s = input("Nhập chuỗi s:").strip().replace('  ',' ')

valid = answer = ""

for word in s.split(' '):
    valid += word
    
    if valid.count(word) == 1: 
        answer += word + " "
    
answer

# %%
#Bài 9: Yêu cầu người dùng cung cấp một chuỗi và cho biết đó có phải một palindrome không
def answer(s):
    
    if len(s)%2==1:
        print(s[:len(s)//2] , s[:len(s)//2:-1])
        
        if s[:len(s)//2] == s[:len(s)//2:-1]:
            print('Yes')
        else:
            print('No')
            
            
    if len(s)%2==0:
        print(s[:len(s)//2] , s[:len(s)//2-1:-1])
        
        if s[:len(s)//2] == s[:len(s)//2-1:-1]:
            print('Yes')
        else:
            print('No')
    
    
a = str(input('Nhập chuỗi:'))
answer(a)
# Out:
# Nhập chuỗi: abcdcba
# abc abc
# Yes

# %%
#Bài 10:Viết một chương trình chấp nhận chuỗi từ được phân tách bằng khoảng trống và in các từ chỉ gồm chữ số.
import re

string = input("nhập câu lệnh vào: ")
pattern = '\d+'

# Phương thức re.findall() trả về một danh sách các chuỗi chứa tất cả các kết quả khớp với pattern đưa ra.
result = re.findall(pattern, string) 
print(result)
# Out:
# nhập câu lệnh vào:  minh sinh ngay 28 thang 9 nam 1994
# ['28', '9', '1994']

# %%
#Bài 11:
def Roman_to_Int(s):
    answer = 0
    value = {"I":1, "V":5, "X":10, "L":50, "C":100, "D":500, "M":1000}
    
    for i in range(len(s)):
        if i==0:
            answer = answer +value[s[i]]
        else:
            if value[s[i]] > value[s[i-1]]:
                answer = answer + value[s[i]] - 2*value[s[i-1]]
            else:
                answer = answer + value[s[i]]
    return answer
                
                
a=input('Nhập số la mã:')
print("Giá trị số nguyên tương ứng:", Roman_to_Int(a))
# Out:
# Nhập số la mã: VIVIVII
# Giá trị số nguyên tương ứng: 15
